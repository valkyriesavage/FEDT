# %% [markdown]
# [Design, Mould, Grow! paper: design tool and characterization section](https://dl.acm.org/doi/full/10.1145/3544548.3580958#d1e1179)
# ![Screenshot 2024-05-08 at 11.08.43.png](attachment:8bc6aa4a-b1eb-4eae-87a6-dd45b1f737e1.png)
# ![image.png](attachment:c5faeeb2-04c3-46a2-970a-d7a3a23bb841.png)
# ![Screenshot 2024-05-08 at 11.09.22.png](attachment:85f2f4b8-7c34-49e4-98e9-24d0f33e871e.png)
# ![Screenshot 2024-05-08 at 11.10.14.png](attachment:3c71ac3e-c67d-4ab7-99b8-26edda4fa549.png)
# ![Screenshot 2024-05-08 at 11.10.44.png](attachment:0be53c8d-70aa-46b7-895a-7db6037feb3a.png)
# ![Screenshot 2024-05-08 at 11.10.32.png](attachment:94986e8e-038c-4cab-9c8b-b41cadf2a748.png)
# ![Screenshot 2024-05-08 at 11.11.16.png](attachment:f6988886-0b4b-42b4-bd4e-99a0cec003e1.png)
# ![Screenshot 2024-05-08 at 11.11.24.png](attachment:87036b5f-24d7-4ef4-a27b-bcd5daa92022.png)
# ![Screenshot 2024-05-08 at 11.11.55.png](attachment:d031fc32-36f3-4a09-8f37-224b7d5d2388.png)

# %% [markdown]
# # Experiment 1a : materials, geometric features, and shrinkage
# ## 1. Specify all parameters to be varied

# %%
from fedt import *

experiment = FEDTExperiment()
experiment.configure_for_printing()

experiment.CAD_variables = [{
        NAME : 'geometric features',
        DATA_TYPE : 'categorical',
        TEST_VALUES : ["circular","spherical", "corners", "ramps", "repeating lines", "different kinds of textures"],
        INSTRUCTION : 'include geometric features of {}'
    }]

experiment.post_process_variables = [{
        NAME : 'material',
        DATA_TYPE : 'categorical',
        TEST_VALUES : ["substrate in the grow kit", "including waste coffee grounds at 10:3 by weight"],
        INSTRUCTION : 'use the {} material in the printed mould'
    }]
experiment.post_process_repetitions = 2

experiment.add_non_crossed_condition({
    CAD: {'geometric features':'circular'},
    POST_PROCESS: {'material':'substrate in the grow kit, with glycerine'}
})

experiment.measurement_variables = [{
        NAME : 'fabricated object error mm from CAD design in patterned areas',
        DATA_TYPE : 'ratio'
    },{
        NAME : 'dimensional change % from CAD design',
        DATA_TYPE : 'ratio'
    },{
        NAME : 'observed warping, detail, and notes',
        DATA_TYPE : 'qualitative'
    }
]
experiment.measurement_repetitions = 1

###########

experiment.experiment_size()

experiment.create_experiment_csv(experiment_csv="designmouldgrow1.csv")
# Out:
# This experiment will require fabricating 25 unique objects.
# 75 total measurements will be recorded.
# ('designmouldgrow1.csv', 'designmouldgrow1_key.csv')

# %% [markdown]
# ## 2. CAM

# %%
experiment.prep_cam()

# %% [markdown]
# ## 3. CAD

# %%
# nothing to do

# %% [markdown]
# ## 4. Fabrication

# %%
experiment.fabricate()
# Out:
# create geometry which has the following values: {'include geometric features of {}': 'circular'}
# enter the file location of this geometry file: circular.stl
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment.fabricate()
#
# File ~/projects/fedtlike/FEDT/fedt.py:249, in FEDTExperiment.fabricate(self)
#     246     CAM_vars = self.dictionaryfy(CAM_vars)
#     248     geom_file = self.cad_executor.build_geometry(geometry_function=self.geometry_function, label_function=self.label_function, label=label, CAD_vars=CAD_vars)
# --> 249     CAM_path = self.cam_executor.do_cam(geom_file, CAM_vars)
#     250     CAM_paths.append(CAM_path)
#     252 self.CAM_paths = CAM_paths
#
# File ~/projects/fedtlike/FEDT/fedt_print.py:39, in FEDTPrinter.do_cam(self, stl_location, argdict)
#      37     slice_command.extend(list(keyval))
#      38 slice_command.extend(['--export-gcode', stl_location])
# ---> 39 results = subprocess.check_output(slice_command)
#      41 # the last line from Prusa Slicer is "Slicing result exported to ..."
#      42 last_line = results.decode('utf-8').strip().split("\n")[-1]
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:1024, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1020         if self.text_mode:
#    1021             self.stderr = io.TextIOWrapper(self.stderr,
#    1022                     encoding=encoding, errors=errors)
# -> 1024     self._execute_child(args, executable, preexec_fn, close_fds,
#    1025                         pass_fds, cwd, env,
#    1026                         startupinfo, creationflags, shell,
#    1027                         p2cread, p2cwrite,
#    1028                         c2pread, c2pwrite,
#    1029                         errread, errwrite,
#    1030                         restore_signals,
#    1031                         gid, gids, uid, umask,
#    1032                         start_new_session, process_group)
#    1033 except:
#    1034     # Cleanup if the child failed starting.
#    1035     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:1917, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1915     if errno_num != 0:
#    1916         err_msg = os.strerror(errno_num)
# -> 1917     raise child_exception_type(errno_num, err_msg, err_filename)
#    1918 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Applications/PrusaSlicer.app/Contents/MacOS/PrusaSlicer'

# %% [markdown]
# ## 5. Post-Processing

# %%
experiment.post_process()

# %% [markdown]
# ## 6. Create measurement framework / user interaction

# %%
experiment.interact()

experiment.measure()

# %% [markdown]
# ## 8. Tea-based hypothesis testing

# %%
#from fedt_tea import do_experiment

# tea_results = do_experiment(measurement_variables,
#                             tea_hypothesis,
#                             experiment_csv,
#                             CAD_variables,
#                             CAM_variables,
#                             post_process_variables,
#                             interaction_variables)

# %% [markdown]
# ## 9. Reporting

# %%
print(experiment.report_latex())
# Out:
# We used drawsvg to create our geometries.
#         We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm. We generated different CAM settings:material (values ['lauan solid wood', 'lauan plywood', 'Japanese cypress', 'paulownia', 'Magnolia obovata', 'Japanese cedar', 'basswood', 'beech', 'oak', 'walnut'])treatment (values ['none', 'fire retardant']).
#         We fabricated objects of each configuration 1 times. We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm.
#         In all, we fabricated 20 objects.
#
#
#          We recorded  conductivity. 1 times for each object (20 total measurements).
# conductivity ranged from 21--216897612 UNIT (mean 21704650.1 UNIT, std 66753500.58241343 UNIT) across all samples. ...

# %% [markdown]
# # Experiment 1b : speed and power
# ## 1. Specify all parameters to be varied

# %%
experiment = FEDTExperiment()
experiment.configure_for_drawsvg()
experiment.configure_for_lasercutting()

experiment.CAM_variables = [{
        NAME : 'speed',
        DATA_TYPE : 'ratio',
        TEST_VALUES : list(np.arange(20,81,10)),
        ARGNAME : 'speed'
    },
    {
        NAME : 'power',
        DATA_TYPE : 'ratio',
        TEST_VALUES : list(np.arange(10,51,5)),
        ARGNAME : 'power'
    }]

experiment.measurement_variables = [{
        NAME : 'conductivity',
        DATA_TYPE : 'ratio'
    }
]
experiment.measurement_repetitions = 1

###########

experiment.experiment_size()

experiment.create_experiment_csv(experiment_csv="circwood1b.csv")
# Out:
# This experiment will require fabricating 63 unique objects.
# 63 total measurements will be recorded.
# ('circwood1b.csv', 'circwood1b_key.csv')

# %% [markdown]
# ## 2. CAM

# %%
experiment.prep_cam()
# Out:
# please open Visicut and Options > Import Settings > fedt_generated.vcsettings

# %% [markdown]
# ## 3. CAD

# %%
# nothing to do
experiment.geometry_function = fedt_2D_geom.drawcircle

# %% [markdown]
# ## 4. Fabrication

# %%
experiment.fabricate()
# Out:
# openjdk version "17.0.6" 2023-01-17
# OpenJDK Runtime Environment Temurin-17.0.6+10 (build 17.0.6+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.6+10 (build 17.0.6+10, mixed mode)
# Unknown command line option: --laserdevice Epilog Helix
# Use -h or --help for help
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment.fabricate()
#
# File ~/projects/fedtlike/FEDT/fedt.py:205, in FEDTExperiment.fabricate(self)
#     203 self.CAM_paths = CAM_paths
#     204 for path in CAM_paths:
# --> 205     self.fabricate_executor.fabricate(path)
#
# File ~/projects/fedtlike/FEDT/fedt_laser.py:117, in FEDTLaser.fabricate(self, cut_file, mapping_file)
#     112 os.rename(temp_zf, temp_plf)
#     113 cut_command = [VISICUT_LOCATION,
#     114             '--laserdevice ' + self.laserdevice,
#     115             '--execute',
#     116             temp_plf]
# --> 117 results = subprocess.check_output(cut_command)
#     118 os.remove(temp_plf)
#     119 return results
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/vwn277/projects/fedtlike/visicut/VisiCut.MacOS', '--laserdevice Epilog Helix', '--execute', 'spam.plf']' returned non-zero exit status 1.

# %% [markdown]
# ## 5. Post-Processing

# %%
experiment.post_process()

# %% [markdown]
# ## 6. Create measurement framework / user interaction

# %%
experiment.interact()

experiment.measure()

# %% [markdown]
# ## 8. Tea-based hypothesis testing

# %%
#from fedt_tea import do_experiment

# tea_results = do_experiment(measurement_variables,
#                             tea_hypothesis,
#                             experiment_csv,
#                             CAD_variables,
#                             CAM_variables,
#                             post_process_variables,
#                             interaction_variables)

# %% [markdown]
# ## 9. Reporting

# %%
print(experiment.report_latex())
# Out:
# We used drawsvg to create our geometries.
#         We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm. We generated different CAM settings:material (values ['lauan solid wood', 'lauan plywood', 'Japanese cypress', 'paulownia', 'Magnolia obovata', 'Japanese cedar', 'basswood', 'beech', 'oak', 'walnut'])treatment (values ['none', 'fire retardant']).
#         We fabricated objects of each configuration 1 times. We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm.
#         In all, we fabricated 20 objects.
#
#
#          We recorded  conductivity. 1 times for each object (20 total measurements).
# conductivity ranged from 21--216897612 UNIT (mean 21704650.1 UNIT, std 66753500.58241343 UNIT) across all samples. ...

# %% [markdown]
# # Experiment 1c : number of laser scans
# ## 1. Specify all parameters to be varied

# %%
from fedt import *
import numpy as np

experiment = FEDTExperiment()
experiment.configure_for_drawsvg()
experiment.configure_for_lasercutting()

experiment.CAD_variables = [{
        NAME : 'number of overlaid lines',
        DATA_TYPE : 'ratio',
        TEST_VALUES : list(np.arange(1,16,1)),
        ARGNAME : 'duplicates'
    }] 
'''
Valkyrie's note: I think "number of laser scans" could be captured as either a CAD variable
(number of overlaid lines) or a fab variable (number of repetitions of an action).
'''

experiment.measurement_variables = [{
        NAME : 'conductivity',
        DATA_TYPE : 'ratio'
    }
]
experiment.measurement_repetitions = 1

experiment.label_gen_function = incrementing_labels

###########

experiment.experiment_size()

experiment.create_experiment_csv(experiment_csv="circwood1c.csv")
# Out:
# This experiment will require fabricating 15 unique objects.
# 15 total measurements will be recorded.
# ('circwood1c.csv', 'circwood1c_key.csv')

# %% [markdown]
# ## 2. CAM

# %%
experiment.prep_cam()
# Out:
# please open Visicut and Options > Import Settings > fedt_generated.vcsettings

# %% [markdown]
# ## 3. CAD

# %%
def drawnumcircles(draw, d, CAD_vars):
    duplicates = CAD_vars['duplicates']
    for i in range(duplicates):
        d.append(draw.Circle(-40, -10, 30,
                fill='none', stroke_width=1, stroke='red'))

experiment.geometry_function = drawnumcircles

# %% [markdown]
# ## 4. Fabrication

# %%
experiment.fabricate()
# Out:
# {'duplicates': 1}
# {'duplicates': 2}
# {'duplicates': 3}
# {'duplicates': 4}
# {'duplicates': 5}
# {'duplicates': 6}
# {'duplicates': 7}
# {'duplicates': 8}
# {'duplicates': 9}
# {'duplicates': 10}
# {'duplicates': 11}
# {'duplicates': 12}
# {'duplicates': 13}
# {'duplicates': 14}
# {'duplicates': 15}
# openjdk version "17.0.6" 2023-01-17
# OpenJDK Runtime Environment Temurin-17.0.6+10 (build 17.0.6+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.6+10 (build 17.0.6+10, mixed mode)
# Unknown command line option: --laserdevice Epilog Helix
# Use -h or --help for help
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment.fabricate()
#
# File ~/projects/fedtlike/FEDT/fedt.py:213, in FEDTExperiment.fabricate(self)
#     211 self.CAM_paths = CAM_paths
#     212 for path in CAM_paths:
# --> 213     self.fabricate_executor.fabricate(path)
#
# File ~/projects/fedtlike/FEDT/fedt_laser.py:117, in FEDTLaser.fabricate(self, cut_file, mapping_file)
#     112 os.rename(temp_zf, temp_plf)
#     113 cut_command = [VISICUT_LOCATION,
#     114             '--laserdevice ' + self.laserdevice,
#     115             '--execute',
#     116             temp_plf]
# --> 117 results = subprocess.check_output(cut_command)
#     118 os.remove(temp_plf)
#     119 return results
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/vwn277/projects/fedtlike/visicut/VisiCut.MacOS', '--laserdevice Epilog Helix', '--execute', 'spam.plf']' returned non-zero exit status 1.

# %% [markdown]
# ## 5. Post-Processing

# %%
experiment.post_process()

# %% [markdown]
# ## 6. Create measurement framework / user interaction

# %%
experiment.interact()

experiment.measure()

# %% [markdown]
# ## 8. Tea-based hypothesis testing

# %%
#from fedt_tea import do_experiment

# tea_results = do_experiment(measurement_variables,
#                             tea_hypothesis,
#                             experiment_csv,
#                             CAD_variables,
#                             CAM_variables,
#                             post_process_variables,
#                             interaction_variables)

# %% [markdown]
# ## 9. Reporting

# %%
print(experiment.report_latex())
# Out:
# We used drawsvg to create our geometries.
#         We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm. We generated different CAM settings:material (values ['lauan solid wood', 'lauan plywood', 'Japanese cypress', 'paulownia', 'Magnolia obovata', 'Japanese cedar', 'basswood', 'beech', 'oak', 'walnut'])treatment (values ['none', 'fire retardant']).
#         We fabricated objects of each configuration 1 times. We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm.
#         In all, we fabricated 20 objects.
#
#
#          We recorded  conductivity. 1 times for each object (20 total measurements).
# conductivity ranged from 21--216897612 UNIT (mean 21704650.1 UNIT, std 66753500.58241343 UNIT) across all samples. ...

# %% [markdown]
# # Experiment 2: Effect of grain direction
# ## 1. Specify all parameters to be varied

# %%
experiment = FEDTExperiment()
experiment.configure_for_drawsvg()
experiment.configure_for_lasercutting()

experiment.CAD_variables = [{
        NAME : 'number of parallel paths',
        DATA_TYPE : 'ratio',
        TEST_VALUES : list(np.arange(1,5,1)),
        ARGNAME : 'nested'
    }]

experiment.CAM_variables = [{
        NAME : 'grain orientation',
        DATA_TYPE : 'categorical',
        TEST_VALUES : ["parallel", "orthogonal"],
        ARGNAME : 'material'
    }]
experiment.fab_repetitions = 1

experiment.measurement_variables = [{
        NAME : 'conductivity',
        DATA_TYPE : 'ratio'
    }
]
experiment.measurement_repetitions = 1

###########

experiment.experiment_size()

experiment.create_experiment_csv(experiment_csv="circwood2.csv")
# Out:
# This experiment will require fabricating 2 unique objects.
# 2 total measurements will be recorded.
# ('circwood2.csv', 'circwood2_key.csv')

# %% [markdown]
# ## 2. CAM

# %%
experiment.prep_cam()
# Out:
# please open Visicut and Options > Import Settings > fedt_generated.vcsettings

# %% [markdown]
# ## 3. CAD

# %%
def drawnestedcircles(draw, d, nested=1):
    for i in range(nested):
        d.append(draw.Circle(-40, -10, 30-nested,
                fill='none', stroke_width=1, stroke='red'))

experiment.geometry_function = drawnestedcircles

# %% [markdown]
# ## 4. Fabrication

# %%
experiment.fabricate()
# Out:
# openjdk version "17.0.6" 2023-01-17
# OpenJDK Runtime Environment Temurin-17.0.6+10 (build 17.0.6+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.6+10 (build 17.0.6+10, mixed mode)
# Unknown command line option: --laserdevice Epilog Helix
# Use -h or --help for help
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment.fabricate()
#
# File ~/projects/fedtlike/FEDT/fedt.py:205, in FEDTExperiment.fabricate(self)
#     203 self.CAM_paths = CAM_paths
#     204 for path in CAM_paths:
# --> 205     self.fabricate_executor.fabricate(path)
#
# File ~/projects/fedtlike/FEDT/fedt_laser.py:117, in FEDTLaser.fabricate(self, cut_file, mapping_file)
#     112 os.rename(temp_zf, temp_plf)
#     113 cut_command = [VISICUT_LOCATION,
#     114             '--laserdevice ' + self.laserdevice,
#     115             '--execute',
#     116             temp_plf]
# --> 117 results = subprocess.check_output(cut_command)
#     118 os.remove(temp_plf)
#     119 return results
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/vwn277/projects/fedtlike/visicut/VisiCut.MacOS', '--laserdevice Epilog Helix', '--execute', 'spam.plf']' returned non-zero exit status 1.

# %% [markdown]
# ## 5. Post-Processing

# %%
experiment.post_process()

# %% [markdown]
# ## 6. Create measurement framework / user interaction

# %%
experiment.interact()

experiment.measure()

# %% [markdown]
# ## 8. Tea-based hypothesis testing

# %%
#from fedt_tea import do_experiment

# tea_results = do_experiment(measurement_variables,
#                             tea_hypothesis,
#                             experiment_csv,
#                             CAD_variables,
#                             CAM_variables,
#                             post_process_variables,
#                             interaction_variables)

# %% [markdown]
# ## 9. Reporting

# %%
print(experiment.report_latex())
# Out:
# We used drawsvg to create our geometries.
#         We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm. We generated different CAM settings:material (values ['lauan solid wood', 'lauan plywood', 'Japanese cypress', 'paulownia', 'Magnolia obovata', 'Japanese cedar', 'basswood', 'beech', 'oak', 'walnut'])treatment (values ['none', 'fire retardant']).
#         We fabricated objects of each configuration 1 times. We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm.
#         In all, we fabricated 20 objects.
#
#
#          We recorded  conductivity. 1 times for each object (20 total measurements).
# conductivity ranged from 21--216897612 UNIT (mean 21704650.1 UNIT, std 66753500.58241343 UNIT) across all samples. ...

# %% [markdown]
# # Experiment 3 : Resistance change over time
# ## 1. Specify all parameters to be varied

# %%
from fedt import *
import fedt_2D_geom

experiment = FEDTExperiment()
experiment.configure_for_drawsvg()
experiment.configure_for_lasercutting()

experiment.post_process_variables = [{
        NAME : 'material',
        DATA_TYPE : 'categorical',
        TEST_VALUES : ["nothing", "varnish"],
        INSTRUCTION : 'coat the material with {}'
    }]
experiment.post_process_repetitions = 4

#### here's something that doesn't fit well into the paradigm: the passage of time
experiment.interaction_variables = [{
        NAME : 'time passed',
        DATA_TYPE : 'ratio',
        TEST_VALUES : list(np.arange(0,7,1)),
        INSTRUCTION : 'allow {} months to pass'
    }]

experiment.measurement_variables = [{
        NAME : 'conductivity',
        DATA_TYPE : 'ratio'
    }
]
experiment.measurement_repetitions = 1

###########

experiment.experiment_size()

experiment.create_experiment_csv(experiment_csv="circwood3.csv")
# Out:
# This experiment will require fabricating 20 unique objects.
# 20 total measurements will be recorded.
# ('circwood1.csv', 'circwood1_key.csv')

# %% [markdown]
# ## 2. CAM

# %%
experiment.prep_cam()
# Out:
# please open Visicut and Options > Import Settings > fedt_generated.vcsettings

# %% [markdown]
# ## 3. CAD

# %%
# nothing to do
experiment.geometry_function = fedt_2D_geom.drawcircle

# %% [markdown]
# ## 4. Fabrication

# %%
experiment.fabricate()
# Out:
# openjdk version "17.0.6" 2023-01-17
# OpenJDK Runtime Environment Temurin-17.0.6+10 (build 17.0.6+10)
# OpenJDK 64-Bit Server VM Temurin-17.0.6+10 (build 17.0.6+10, mixed mode)
# Unknown command line option: --laserdevice Epilog Helix
# Use -h or --help for help
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 experiment.fabricate()
#
# File ~/projects/fedtlike/FEDT/fedt.py:205, in FEDTExperiment.fabricate(self)
#     203 self.CAM_paths = CAM_paths
#     204 for path in CAM_paths:
# --> 205     self.fabricate_executor.fabricate(path)
#
# File ~/projects/fedtlike/FEDT/fedt_laser.py:117, in FEDTLaser.fabricate(self, cut_file, mapping_file)
#     112 os.rename(temp_zf, temp_plf)
#     113 cut_command = [VISICUT_LOCATION,
#     114             '--laserdevice ' + self.laserdevice,
#     115             '--execute',
#     116             temp_plf]
# --> 117 results = subprocess.check_output(cut_command)
#     118 os.remove(temp_plf)
#     119 return results
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File ~/miniforge3/envs/jupyfab/lib/python3.11/subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/vwn277/projects/fedtlike/visicut/VisiCut.MacOS', '--laserdevice Epilog Helix', '--execute', 'spam.plf']' returned non-zero exit status 1.

# %% [markdown]
# ## 5. Post-Processing

# %%
experiment.post_process()

# %% [markdown]
# ## 6. Create measurement framework / user interaction

# %%
experiment.interact()

experiment.measure()

# %% [markdown]
# ## 8. Tea-based hypothesis testing

# %%
#from fedt_tea import do_experiment

# tea_results = do_experiment(measurement_variables,
#                             tea_hypothesis,
#                             experiment_csv,
#                             CAD_variables,
#                             CAM_variables,
#                             post_process_variables,
#                             interaction_variables)

# %% [markdown]
# ## 9. Reporting

# %%
print(experiment.report_latex())
# Out:
# We used drawsvg to create our geometries.
#         We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm. We generated different CAM settings:material (values ['lauan solid wood', 'lauan plywood', 'Japanese cypress', 'paulownia', 'Magnolia obovata', 'Japanese cedar', 'basswood', 'beech', 'oak', 'walnut'])treatment (values ['none', 'fire retardant']).
#         We fabricated objects of each configuration 1 times. We used a Epilog Helix with bed size {'width': 609.6, 'height': 457.2} and Visicut. Our default settings were cut power:100, speed:100, frequency:5000, material:Acrylic, thickness:3.0mm.
#         In all, we fabricated 20 objects.
#
#
#          We recorded  conductivity. 1 times for each object (20 total measurements).
# conductivity ranged from 21--216897612 UNIT (mean 21704650.1 UNIT, std 66753500.58241343 UNIT) across all samples. ...
